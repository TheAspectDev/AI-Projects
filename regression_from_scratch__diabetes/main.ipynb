# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data = pd.read_csv('diabetes.csv')

# 1 == true
# 0 == false

x = data.drop('Outcome', axis=1)
y = data.Outcome

data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              1       89             66             23       94  28.1
# 1              0      137             40             35      168  43.1
# 2              3       78             50             32       88  31.0
# 3              2      197             70             45      543  30.5
# 4              1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 387            0      181             88             44      510  43.3
# 388            1      128             88             39      110  36.5
# 389            2       88             58             26       16  28.4
# 390           10      101             76             48      180  32.9
# 391            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.167   21        0
# 1                       2.288   33        1
# 2                       0.248   26        1
# 3                       0.158   53        1
# 4                       0.398   59        1
# ..                        ...  ...      ...
# 387                     0.222   26        1
# 388                     1.057   37        1
# 389                     0.766   22        0
# 390                     0.171   63        0
# 391                     0.245   30        0
#
# [392 rows x 9 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
model = LogisticRegression(max_iter=999999999999)
model.fit(X_train, y_train)

accurancy = model.score(X_test, y_test)
print("Accurancy: ", accurancy)
# Out:
# Accurancy:  0.7848101265822784

# %%
#                               Pregnancies	Glucose	BloodPressure	SkinThickness	Insulin	BMI	DiabetesPedigreeFunction	Age

print(model.predict(np.array([[0,          137,     66,              1,             94,     43, 0.6,                        51]])))
# Out:
# [0]
# C:\Users\Aspect\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
